# %%
import numpy as np

A = np.mat("1 -2; 1 3")
print(A)
print("")

evalue, evect = np.linalg.eigh(A)
print(evalue)
print("")
print(evect)
# Out:
# [[ 1 -2]
#  [ 1  3]]
#
# [0.58578644 3.41421356]
#
# [[-0.92387953  0.38268343]
#  [ 0.38268343  0.92387953]]
